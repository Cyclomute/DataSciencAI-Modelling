# %% [markdown]
# ## PCI CONFLICT DETECTION AND AUTOMATIC PCI PLANNING (APP)

# %% [markdown]
# #### Importing required libraries

# %%
# Import the required libraries
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Read in the csv file into a dataframe

# %%
df = pd.read_csv("D:\AA_Download\CSV_4G_PCI_Matje.csv") # read in the csv file

# %% [markdown]
# #### Explore the dataframe and clean the data

# %%
df # check file contents and rows/columns
# Out:
#       Cell name      LONG       LAT  PCI  Territory
# 0        L0002A  3.355111   6.45301  273      APAPA
# 1        L0002B  3.355111   6.45301  274      APAPA
# 2        L0002C  3.355111   6.45301  275      APAPA
# 3        L0002D  3.355111   6.45301  273      APAPA
# 4        L0002E  3.355111   6.45301  274      APAPA
# ...         ...       ...       ...  ...        ...
# 41330  LOG4929J  3.724694  6.896167  447  IJEBU-ODE
# 41331  LOG5543K    3.7176   6.89383  348  IJEBU-ODE
# 41332  LOG5543B    3.7176   6.89383  348  IJEBU-ODE
# 41333  LOG4929K  3.724694  6.896167  448  IJEBU-ODE
# 41334  LOG5831A  3.726764  6.890493  471  IJEBU-ODE
#
# [41335 rows x 5 columns]

# %%
df.isna().sum() # missing entry check
# Out:
# Cell name    0
# LONG         0
# LAT          0
# PCI          0
# Territory    0
# dtype: int64

# %%
df["Territory"].unique() # unique territory checks
# Out:
# array(['APAPA', 'LAGOS ISLAND', 'IKEJA', 'KOSOFE', 'ALIMOSHO',
#        'LAGOS MAINLAND', 'SANGO', 'FESTAC', 'MUSHIN', 'AGEGE',
#        'IJEBU-ODE', 'ABEOKUTA', 'IKORODU', 'OGBOMOSHO', 'Ikeja',
#        'ETI OSA', 'BADAGRY', 'SURULERE', ' IJEBU-ODE', 'EPE', 'Ikorodu',
#        'LAGOS', 'OGUN WATERSIDE', 'ONDO'], dtype=object)

# %%
df.duplicated().sum() # checking for duplicates
# Out:
# 18

# %%
# Remove duplicates based on Cell name
df = df.drop_duplicates(subset='Cell name', keep='first').reset_index(drop=True)

# %%
df.duplicated().sum() # confirming duplicate removal
# Out:
# 0

# %%
df.info() # checking datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41302 entries, 0 to 41301
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Cell name  41302 non-null  object
#  1   LONG       41302 non-null  object
#  2   LAT        41302 non-null  object
#  3   PCI        41302 non-null  int64
#  4   Territory  41302 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.6+ MB

# %%
df["LONG"] = df["LONG"].astype(float) # converting longitude to float
df["LAT"] = df["LAT"].astype(float) # converting latitude to float

# %%
df.info() # cross-checking datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41302 entries, 0 to 41301
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Cell name  41302 non-null  object
#  1   LONG       41302 non-null  float64
#  2   LAT        41302 non-null  float64
#  3   PCI        41302 non-null  int64
#  4   Territory  41302 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Automation: Find PCI conflicts within 1km and replan where necessary

# %%
# importing required library to compute geo-distance
from geopy.distance import geodesic

# %% [markdown]
# ### IKEJA TERRITORY

# %%
# Filter DataFrame to only include cells in the "IKEJA" territory
df_ikeja = df[df['Territory'] == 'IKEJA']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "IKEJA" territory
pci_clashes = calculate_distances_and_replan_pci(df_ikeja)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_ikeja.to_csv('updated_ikeja_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_ikeja_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### KOSOFE TERRITORY

# %%
# Filter DataFrame to only include cells in the "KOSOFE" territory
df_kosofe = df[df['Territory'] == 'KOSOFE']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "KOSOFE" territory
pci_clashes = calculate_distances_and_replan_pci(df_kosofe)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_kosofe.to_csv('updated_kosofe_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_kosofe_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# PCI Clashes found and replanned:
# Cells LLG3203A and LLG3621A had the same PCI (192) and were 0.40 km apart.
# Cells LLG3203A and LLG3621D had the same PCI (192) and were 0.40 km apart.
# Cells LLG3203A and LLG3621G had the same PCI (192) and were 0.40 km apart.
# Cells LLG3203A and LLG3621X had the same PCI (192) and were 0.40 km apart.
# Cells LLG3203B and LLG3621B had the same PCI (193) and were 0.40 km apart.
# Cells LLG3203B and LLG3621E had the same PCI (193) and were 0.40 km apart.
# Cells LLG3203B and LLG3621H had the same PCI (193) and were 0.40 km apart.
# Cells LLG3203B and LLG3621Y had the same PCI (193) and were 0.40 km apart.
# Cells LLG3203C and LLG3621C had the same PCI (194) and were 0.40 km apart.
# Cells LLG3203C and LLG3621F had the same PCI (194) and were 0.40 km apart.
# Cells LLG3203C and LLG3621I had the same PCI (194) and were 0.40 km apart.
# Cells LLG3203C and LLG3621Z had the same PCI (194) and were 0.40 km apart.
#
# Updated DataFrame saved to 'updated_kosofe_cells.csv'.

# %% [markdown]
# ### AGEGE TERRITORY

# %%
# Filter DataFrame to only include cells in the "AGEGE" territory
df_agege = df[df['Territory'] == 'AGEGE']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "AGEGE" territory
pci_clashes = calculate_distances_and_replan_pci(df_agege)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_agege.to_csv('updated_agege_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_agege_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### APAPA TERRITORY

# %%
# Filter DataFrame to only include cells in the "APAPA" territory
df_apapa = df[df['Territory'] == 'APAPA']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "APAPA" territory
pci_clashes = calculate_distances_and_replan_pci(df_apapa)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_apapa.to_csv('updated_apapa_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_apapa_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### SURULERE, LAGOS, BADAGRY, EPE, OGUN WATERSIDE, ONDO, AND OGBOMOSHO TERRITORIES

# %%
# Filter DataFrame to only include cells in the specified territories
combined_territories = ['SURULERE', 'LAGOS', 'BADAGRY', 'EPE', 'OGUN WATERSIDE', 'ONDO', 'OGBOMOSHO']
df_combined = df[df['Territory'].isin(combined_territories)]

# Function to calculate distance between all cells within specified territories and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the combined territories
pci_clashes = calculate_distances_and_replan_pci(df_combined)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_combined.to_csv('updated_combined_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_combined_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### LAGOS MAINLAND TERRITORY

# %%
# Filter DataFrame to only include cells in the "LAGOS MAINLAND" territory
df_lagos_mainland = df[df['Territory'] == 'LAGOS MAINLAND']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "LAGOS MAINLAND" territory
pci_clashes = calculate_distances_and_replan_pci(df_lagos_mainland)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_lagos_mainland.to_csv('updated_lagos_mainland_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_lagos_mainland_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# PCI Clashes found and replanned:
# Cells LLG2034A and LLG3982A had the same PCI (151) and were 0.95 km apart.
# Cells LLG2034A and LLG3982D had the same PCI (151) and were 0.95 km apart.
# Cells LLG2034A and LLG3982G had the same PCI (151) and were 0.95 km apart.
# Cells LLG2034A and LLG3982J had the same PCI (151) and were 0.95 km apart.
# Cells LLG2034A and LLG3982X had the same PCI (151) and were 0.95 km apart.
# Cells LLG2034B and LLG3982B had the same PCI (150) and were 0.95 km apart.
# Cells LLG2034B and LLG3982E had the same PCI (150) and were 0.95 km apart.
# Cells LLG2034B and LLG3982H had the same PCI (150) and were 0.95 km apart.
# Cells LLG2034B and LLG3982K had the same PCI (150) and were 0.95 km apart.
# Cells LLG2034B and LLG3982Y had the same PCI (150) and were 0.95 km apart.
# Cells LLG2034C and LLG3982C had the same PCI (152) and were 0.95 km apart.
# Cells LLG2034C and LLG3982F had the same PCI (152) and were 0.95 km apart.
# Cells LLG2034C and LLG3982I had the same PCI (152) and were 0.95 km apart.
# Cells LLG2034C and LLG3982L had the same PCI (152) and were 0.95 km apart.
# Cells LLG2034C and LLG3982Z had the same PCI (152) and were 0.95 km apart.
#
# Updated DataFrame saved to 'updated_lagos_mainland_cells.csv'.

# %% [markdown]
# ### IKORODU TERRITORY

# %%
# Filter DataFrame to only include cells in the "IKORODU" territory
df_ikorodu = df[df['Territory'] == 'IKORODU']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "IKORODU" territory
pci_clashes = calculate_distances_and_replan_pci(df_ikorodu)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_ikorodu.to_csv('updated_ikorodu_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_ikorodu_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### MUSHIN TERRITORY

# %%
# Filter DataFrame to only include cells in the "MUSHIN" territory
df_mushin = df[df['Territory'] == 'MUSHIN']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "MUSHIN" territory
pci_clashes = calculate_distances_and_replan_pci(df_mushin)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_mushin.to_csv('updated_mushin_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_mushin_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### SANGO TERRITORY

# %%
# Filter DataFrame to only include cells in the "SANGO" territory
df_sango = df[df['Territory'] == 'SANGO']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "SANGO" territory
pci_clashes = calculate_distances_and_replan_pci(df_sango)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_sango.to_csv('updated_sango_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_sango_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### FESTAC TERRITORY

# %%
# Filter DataFrame to only include cells in the "FESTAC" territory
df_festac = df[df['Territory'] == 'FESTAC']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "FESTAC" territory
pci_clashes = calculate_distances_and_replan_pci(df_festac)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_festac.to_csv('updated_festac_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_festac_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# PCI Clashes found and replanned:
# Cells LLG1057P and LLG2658B had the same PCI (208) and were 0.76 km apart.
# Cells LLG1057P and LLG2658E had the same PCI (208) and were 0.76 km apart.
# Cells LLG1057P and LLG2658H had the same PCI (208) and were 0.76 km apart.
#
# Updated DataFrame saved to 'updated_festac_cells.csv'.

# %% [markdown]
# ### ABEOKUTA TERRITORY

# %%
# Filter DataFrame to only include cells in the "ABEOKUTA" territory
df_abeokuta = df[df['Territory'] == 'ABEOKUTA']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "ABEOKUTA" territory
pci_clashes = calculate_distances_and_replan_pci(df_abeokuta)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_abeokuta.to_csv('updated_abeokuta_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_abeokuta_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### ALIMOSHO TERRITORY

# %%
# Filter DataFrame to only include cells in the "ALIMOSHO" territory
df_alimosho = df[df['Territory'] == 'ALIMOSHO']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "ALIMOSHO" territory
pci_clashes = calculate_distances_and_replan_pci(df_alimosho)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_alimosho.to_csv('updated_alimosho_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_alimosho_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# PCI Clashes found and replanned:
# Cells L6265A and LLG5788A had the same PCI (387) and were 0.95 km apart.
# Cells L6265A and LLG5788D had the same PCI (387) and were 0.95 km apart.
# Cells L6265A and LLG5788G had the same PCI (387) and were 0.95 km apart.
# Cells L6265A and LLG5788X had the same PCI (387) and were 0.95 km apart.
# Cells L6265B and LLG5788B had the same PCI (388) and were 0.95 km apart.
# Cells L6265B and LLG5788E had the same PCI (388) and were 0.95 km apart.
# Cells L6265B and LLG5788H had the same PCI (388) and were 0.95 km apart.
# Cells L6265B and LLG5788Y had the same PCI (388) and were 0.95 km apart.
# Cells L6265C and LLG5788C had the same PCI (389) and were 0.95 km apart.
# Cells L6265C and LLG5788F had the same PCI (389) and were 0.95 km apart.
# Cells L6265C and LLG5788I had the same PCI (389) and were 0.95 km apart.
# Cells L6265C and LLG5788Z had the same PCI (389) and were 0.95 km apart.
#
# Updated DataFrame saved to 'updated_alimosho_cells.csv'.

# %% [markdown]
# ### IJEBU-ODE TERRITORY

# %%
# Filter DataFrame to only include cells in the "IJEBU-ODE" territory
df_ijebu_ode = df[df['Territory'] == 'IJEBU-ODE']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "IJEBU-ODE" territory
pci_clashes = calculate_distances_and_replan_pci(df_ijebu_ode)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_ijebu_ode.to_csv('updated_ijebu_ode_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_ijebu_ode_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# No PCI clashes found within the distance range of 0.1 km to 1 km.

# %% [markdown]
# ### LAGOS ISLAND TERRITORY

# %%
# Filter DataFrame to only include cells in the "LAGOS ISLAND" territory
df_lagos_island = df[df['Territory'] == 'LAGOS ISLAND']

# Function to calculate distance between all cells within a specified territory and replan clashed PCIs
def calculate_distances_and_replan_pci(df, distance_range=(0.1, 1), available_pcis=range(0, 504)):
    pci_clashes = []
    cell_names = df['Cell name'].values
    latitudes = df['LAT'].values
    longitudes = df['LONG'].values
    pcis = df['PCI'].values
    used_pcis = set(pcis)
    
    for i in range(len(df)):
        coord1 = (latitudes[i], longitudes[i])
        
        for j in range(i + 1, len(df)):
            coord2 = (latitudes[j], longitudes[j])
            distance = geodesic(coord1, coord2).kilometers
            
            # Check for PCI clash within the specified distance range
            if distance_range[0] <= distance < distance_range[1] and pcis[i] == pcis[j]:
                pci_clashes.append((cell_names[i], cell_names[j], pcis[i], distance))
                
                # Find new PCI for one of the clashing cells
                for new_pci in available_pcis:
                    if new_pci not in used_pcis:
                        df.loc[df['Cell name'] == cell_names[j], 'PCI'] = new_pci
                        used_pcis.add(new_pci)
                        break
    
    return pci_clashes

# Calculate distances and replan clashed PCIs in the "LAGOS ISLAND" territory
pci_clashes = calculate_distances_and_replan_pci(df_lagos_island)

# Display PCI clashes and the new DataFrame with updated PCI values
if pci_clashes:
    print("PCI Clashes found and replanned:")
    for clash in pci_clashes:
        print(f"Cells {clash[0]} and {clash[1]} had the same PCI ({clash[2]}) and were {clash[3]:.2f} km apart.")
    
    # Save the updated DataFrame to a CSV file
    df_lagos_island.to_csv('updated_lagos_island_cells.csv', index=False)
    print("\nUpdated DataFrame saved to 'updated_lagos_island_cells.csv'.")
else:
    print("No PCI clashes found within the distance range of 0.1 km to 1 km.")
# Out:
# PCI Clashes found and replanned:
# Cells L6400D and LLG1996C had the same PCI (35) and were 0.79 km apart.
# Cells L6400D and LLG1996F had the same PCI (35) and were 0.79 km apart.
# Cells L6400D and LLG1996I had the same PCI (35) and were 0.79 km apart.
# Cells L6400D and LLG1996L had the same PCI (35) and were 0.79 km apart.
# Cells L6400D and LLG1996Z had the same PCI (35) and were 0.79 km apart.
# Cells L6400D and LLG5991C had the same PCI (35) and were 0.66 km apart.
# Cells L6400D and LLG5991F had the same PCI (35) and were 0.66 km apart.
# Cells L6400D and LLG5991I had the same PCI (35) and were 0.66 km apart.
# Cells L6400D and LLG5991L had the same PCI (35) and were 0.66 km apart.
# Cells L6400E and LLG5991A had the same PCI (33) and were 0.66 km apart.
# Cells L6400E and LLG5991D had the same PCI (33) and were 0.66 km apart.
# Cells L6400E and LLG5991G had the same PCI (33) and were 0.66 km apart.
# Cells L6400E and LLG5991J had the same PCI (33) and were 0.66 km apart.
# Cells L6400F and LLG5991B had the same PCI (34) and were 0.66 km apart.
# Cells L6400F and LLG5991E had the same PCI (34) and were 0.66 km apart.
# Cells L6400F and LLG5991H had the same PCI (34) and were 0.66 km apart.
# Cells L6400F and LLG5991K had the same PCI (34) and were 0.66 km apart.
# Cells L6400G and LLG1996C had the same PCI (35) and were 0.79 km apart.
# Cells L6400G and LLG1996F had the same PCI (35) and were 0.79 km apart.
# Cells L6400G and LLG1996I had the same PCI (35) and were 0.79 km apart.
# Cells L6400G and LLG1996L had the same PCI (35) and were 0.79 km apart.
# Cells L6400G and LLG1996Z had the same PCI (35) and were 0.79 km apart.
# Cells L6400G and LLG5991C had the same PCI (35) and were 0.66 km apart.
# Cells L6400G and LLG5991F had the same PCI (35) and were 0.66 km apart.
# Cells L6400G and LLG5991I had the same PCI (35) and were 0.66 km apart.
# Cells L6400G and LLG5991L had the same PCI (35) and were 0.66 km apart.
# Cells L6400H and LLG5991A had the same PCI (33) and were 0.66 km apart.
# Cells L6400H and LLG5991D had the same PCI (33) and were 0.66 km apart.
# Cells L6400H and LLG5991G had the same PCI (33) and were 0.66 km apart.
# Cells L6400H and LLG5991J had the same PCI (33) and were 0.66 km apart.
# Cells L6400I and LLG5991B had the same PCI (34) and were 0.66 km apart.
# Cells L6400I and LLG5991E had the same PCI (34) and were 0.66 km apart.
# Cells L6400I and LLG5991H had the same PCI (34) and were 0.66 km apart.
# Cells L6400I and LLG5991K had the same PCI (34) and were 0.66 km apart.
# Cells LLG0173D and LLG0177D had the same PCI (494) and were 0.90 km apart.
# Cells LLG0173E and LLG0177E had the same PCI (493) and were 0.90 km apart.
# Cells LLG0173F and LLG0177F had the same PCI (492) and were 0.90 km apart.
# Cells LLG0173G and LLG0177D had the same PCI (494) and were 0.90 km apart.
# Cells LLG0173H and LLG0177E had the same PCI (493) and were 0.90 km apart.
# Cells LLG0173I and LLG0177F had the same PCI (492) and were 0.90 km apart.
# Cells LLG1250A and LLG6094C had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250A and LLG6094F had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250A and LLG6094Z had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250D and LLG6094C had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250D and LLG6094F had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250D and LLG6094Z had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250G and LLG6094C had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250G and LLG6094F had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250G and LLG6094Z had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250J and LLG6094C had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250J and LLG6094F had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250J and LLG6094Z had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250X and LLG6094C had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250X and LLG6094F had the same PCI (501) and were 0.91 km apart.
# Cells LLG1250X and LLG6094Z had the same PCI (501) and were 0.91 km apart.
# Cells LLG1420A and LLG1998B had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420A and LLG1998E had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420A and LLG1998H had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420A and LLG1998K had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420A and LLG1998Y had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420B and LLG1998C had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420B and LLG1998F had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420B and LLG1998I had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420B and LLG1998L had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420B and LLG1998Z had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420C and LLG1998A had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420C and LLG1998D had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420C and LLG1998G had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420C and LLG1998J had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420C and LLG1998X had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420D and LLG1998B had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420D and LLG1998E had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420D and LLG1998H had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420D and LLG1998K had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420D and LLG1998Y had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420E and LLG1998C had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420E and LLG1998F had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420E and LLG1998I had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420E and LLG1998L had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420E and LLG1998Z had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420F and LLG1998A had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420F and LLG1998D had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420F and LLG1998G had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420F and LLG1998J had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420F and LLG1998X had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420G and LLG1998B had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420G and LLG1998E had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420G and LLG1998H had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420G and LLG1998K had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420G and LLG1998Y had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420H and LLG1998C had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420H and LLG1998F had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420H and LLG1998I had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420H and LLG1998L had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420H and LLG1998Z had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420I and LLG1998A had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420I and LLG1998D had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420I and LLG1998G had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420I and LLG1998J had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420I and LLG1998X had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420J and LLG1998B had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420J and LLG1998E had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420J and LLG1998H had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420J and LLG1998K had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420J and LLG1998Y had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420K and LLG1998C had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420K and LLG1998F had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420K and LLG1998I had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420K and LLG1998L had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420K and LLG1998Z had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420L and LLG1998A had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420L and LLG1998D had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420L and LLG1998G had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420L and LLG1998J had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420L and LLG1998X had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420X and LLG1998B had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420X and LLG1998E had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420X and LLG1998H had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420X and LLG1998K had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420X and LLG1998Y had the same PCI (26) and were 0.23 km apart.
# Cells LLG1420Y and LLG1998C had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420Y and LLG1998F had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420Y and LLG1998I had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420Y and LLG1998L had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420Y and LLG1998Z had the same PCI (24) and were 0.23 km apart.
# Cells LLG1420Z and LLG1998A had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420Z and LLG1998D had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420Z and LLG1998G had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420Z and LLG1998J had the same PCI (25) and were 0.23 km apart.
# Cells LLG1420Z and LLG1998X had the same PCI (25) and were 0.23 km apart.
# Cells LLG1422B and LLG1423A had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422B and LLG1423D had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422B and LLG1423G had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422B and LLG1423J had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422C and LLG1423B had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422C and LLG1423E had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422C and LLG1423H had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422C and LLG1423K had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422E and LLG1423A had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422E and LLG1423D had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422E and LLG1423G had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422E and LLG1423J had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422F and LLG1423B had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422F and LLG1423E had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422F and LLG1423H had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422F and LLG1423K had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422H and LLG1423A had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422H and LLG1423D had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422H and LLG1423G had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422H and LLG1423J had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422I and LLG1423B had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422I and LLG1423E had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422I and LLG1423H had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422I and LLG1423K had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422K and LLG1423A had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422K and LLG1423D had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422K and LLG1423G had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422K and LLG1423J had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422L and LLG1423B had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422L and LLG1423E had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422L and LLG1423H had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422L and LLG1423K had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422Y and LLG1423A had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422Y and LLG1423D had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422Y and LLG1423G had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422Y and LLG1423J had the same PCI (32) and were 0.56 km apart.
# Cells LLG1422Z and LLG1423B had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422Z and LLG1423E had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422Z and LLG1423H had the same PCI (31) and were 0.56 km apart.
# Cells LLG1422Z and LLG1423K had the same PCI (31) and were 0.56 km apart.
# Cells LLG1995B and LLG1996A had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995B and LLG1996D had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995B and LLG1996G had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995B and LLG1996J had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995B and LLG1996X had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995C and LLG1996B had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995C and LLG1996E had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995C and LLG1996H had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995C and LLG1996K had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995C and LLG1996Y had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995E and LLG1996A had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995E and LLG1996D had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995E and LLG1996G had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995E and LLG1996J had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995E and LLG1996X had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995F and LLG1996B had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995F and LLG1996E had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995F and LLG1996H had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995F and LLG1996K had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995F and LLG1996Y had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995H and LLG1996A had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995H and LLG1996D had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995H and LLG1996G had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995H and LLG1996J had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995H and LLG1996X had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995I and LLG1996B had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995I and LLG1996E had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995I and LLG1996H had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995I and LLG1996K had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995I and LLG1996Y had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995K and LLG1996A had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995K and LLG1996D had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995K and LLG1996G had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995K and LLG1996J had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995K and LLG1996X had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995L and LLG1996B had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995L and LLG1996E had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995L and LLG1996H had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995L and LLG1996K had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995L and LLG1996Y had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995Y and LLG1996A had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995Y and LLG1996D had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995Y and LLG1996G had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995Y and LLG1996J had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995Y and LLG1996X had the same PCI (498) and were 0.22 km apart.
# Cells LLG1995Z and LLG1996B had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995Z and LLG1996E had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995Z and LLG1996H had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995Z and LLG1996K had the same PCI (499) and were 0.22 km apart.
# Cells LLG1995Z and LLG1996Y had the same PCI (499) and were 0.22 km apart.
# Cells LLG1996C and LLG5991C had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996C and LLG5991F had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996C and LLG5991I had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996C and LLG5991L had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996F and LLG5991C had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996F and LLG5991F had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996F and LLG5991I had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996F and LLG5991L had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996I and LLG5991C had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996I and LLG5991F had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996I and LLG5991I had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996I and LLG5991L had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996L and LLG5991C had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996L and LLG5991F had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996L and LLG5991I had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996L and LLG5991L had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996Z and LLG5991C had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996Z and LLG5991F had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996Z and LLG5991I had the same PCI (35) and were 0.40 km apart.
# Cells LLG1996Z and LLG5991L had the same PCI (35) and were 0.40 km apart.
# Cells LLG1997A and LLG5395D had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997A and LLG5395G had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997D and LLG5395D had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997D and LLG5395G had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997G and LLG5395D had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997G and LLG5395G had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997J and LLG5395D had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997J and LLG5395G had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997X and LLG5395D had the same PCI (21) and were 0.77 km apart.
# Cells LLG1997X and LLG5395G had the same PCI (21) and were 0.77 km apart.
# Cells LLG2762A and LLG5990A had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762A and LLG5990D had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762A and LLG5990G had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762A and LLG5990J had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762B and LLG5990B had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762B and LLG5990E had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762B and LLG5990H had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762B and LLG5990K had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762C and LLG5990C had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762C and LLG5990F had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762C and LLG5990I had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762C and LLG5990L had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762D and LLG5990A had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762D and LLG5990D had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762D and LLG5990G had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762D and LLG5990J had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762E and LLG5990B had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762E and LLG5990E had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762E and LLG5990H had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762E and LLG5990K had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762F and LLG5990C had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762F and LLG5990F had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762F and LLG5990I had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762F and LLG5990L had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762G and LLG5990A had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762G and LLG5990D had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762G and LLG5990G had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762G and LLG5990J had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762H and LLG5990B had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762H and LLG5990E had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762H and LLG5990H had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762H and LLG5990K had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762I and LLG5990C had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762I and LLG5990F had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762I and LLG5990I had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762I and LLG5990L had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762J and LLG5990A had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762J and LLG5990D had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762J and LLG5990G had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762J and LLG5990J had the same PCI (243) and were 0.76 km apart.
# Cells LLG2762K and LLG5990B had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762K and LLG5990E had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762K and LLG5990H had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762K and LLG5990K had the same PCI (244) and were 0.76 km apart.
# Cells LLG2762L and LLG5990C had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762L and LLG5990F had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762L and LLG5990I had the same PCI (245) and were 0.76 km apart.
# Cells LLG2762L and LLG5990L had the same PCI (245) and were 0.76 km apart.
# Cells LLG6053A and LLG6068C had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053A and LLG6068F had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053A and LLG6068I had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053A and LLG6068L had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053A and LLG6068Z had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053B and LLG6068A had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053B and LLG6068D had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053B and LLG6068G had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053B and LLG6068J had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053B and LLG6068X had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053C and LLG6068B had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053C and LLG6068E had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053C and LLG6068H had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053C and LLG6068K had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053C and LLG6068Y had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053D and LLG6068C had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053D and LLG6068F had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053D and LLG6068I had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053D and LLG6068L had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053D and LLG6068Z had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053E and LLG6068A had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053E and LLG6068D had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053E and LLG6068G had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053E and LLG6068J had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053E and LLG6068X had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053F and LLG6068B had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053F and LLG6068E had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053F and LLG6068H had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053F and LLG6068K had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053F and LLG6068Y had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053J and LLG6068C had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053J and LLG6068F had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053J and LLG6068I had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053J and LLG6068L had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053J and LLG6068Z had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053K and LLG6068A had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053K and LLG6068D had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053K and LLG6068G had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053K and LLG6068J had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053K and LLG6068X had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053L and LLG6068B had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053L and LLG6068E had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053L and LLG6068H had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053L and LLG6068K had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053L and LLG6068Y had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053X and LLG6068C had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053X and LLG6068F had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053X and LLG6068I had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053X and LLG6068L had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053X and LLG6068Z had the same PCI (86) and were 0.89 km apart.
# Cells LLG6053Y and LLG6068A had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053Y and LLG6068D had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053Y and LLG6068G had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053Y and LLG6068J had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053Y and LLG6068X had the same PCI (85) and were 0.89 km apart.
# Cells LLG6053Z and LLG6068B had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053Z and LLG6068E had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053Z and LLG6068H had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053Z and LLG6068K had the same PCI (84) and were 0.89 km apart.
# Cells LLG6053Z and LLG6068Y had the same PCI (84) and were 0.89 km apart.
#
# Updated DataFrame saved to 'updated_lagos_island_cells.csv'.
